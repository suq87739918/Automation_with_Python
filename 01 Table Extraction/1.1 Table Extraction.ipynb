# %%
import pandas as pd
import lxml

# %%
#this should get 23 tables
simpsons = pd.read_html("https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)")
print(len(simpsons))
# Out:
# 23

# %%
#get the second table from it
simpsons[1]
# Out:
#     No. overall  No. in season                                Title  \
# 0           1.0            1.0  "Simpsons Roasting on an Open Fire"
# 1           2.0            2.0                    "Bart the Genius"
# 2           NaN            NaN                                  NaN
# 3           3.0            3.0                    "Homer's Odyssey"
# 4           4.0            4.0      "There's No Disgrace Like Home"
# 5           5.0            5.0                   "Bart the General"
# 6           6.0            6.0                       "Moaning Lisa"
# 7           7.0            7.0           "The Call of the Simpsons"
# 8           NaN            NaN                                  NaN
# 9           8.0            8.0                  "The Telltale Head"
# 10          9.0            9.0              "Life on the Fast Lane"
# 11         10.0           10.0                  "Homer's Night Out"
# 12         11.0           11.0                "The Crepes of Wrath"
# ...
